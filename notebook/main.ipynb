# %% [markdown]
# ## Import Lib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import seaborn as sns

# %% [markdown]
# ### 1.1 Read CSV file

# %%
df = pd.read_csv('/Users/witchaponkasettrakarn/Desktop/cctv_prediction/CCTVP/dataset/Raw.csv')

# %%
df
# Out:
#     Sample  TTF of A1  TTF of A2
# 0        1         35         30
# 1        2         35         36
# 2        3         39         38
# 3        4         40         40
# 4        5         41         42
# 5        6         59         58
# 6        7         59         58
# 7        8         60         60
# 8        9         61         65
# 9       10         62         66
# 10      11         70         71
# 11      12         70         71
# 12      13         70         71
# 13      14         73         72
# 14      15         74         73
# 15      16         78         76
# 16      17         78         77
# 17      18         79         78
# 18      19         80         78
# 19      20         81         79
# 20      21         83         80
# 21      22         83         83
# 22      23         85         83
# 23      24         85         84
# 24      25         90         88
# 25      26         88         89
# 26      27         90         90
# 27      28         90         90
# 28      29         91         92
# 29      30         92         94
# 30      31         99         98
# 31      32         99        100
# 32      33         99        100
# 33      34        100        100
# 34      35        100        100
# 35      36        103        106
# 36      37        107        108
# 37      38        108        108
# 38      39        110        112
# 39      40        110        114

# %% [markdown]
# ### 1.2 Plot histogram of Distribution A1 and A2

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.histplot(data=df, x="TTF of A1", kde=True)
sns.histplot(data=df, x="TTF of A2", kde=True)

plt.legend(["TTF of A1", "TTF of A2"])
plt.title("Histogram of TTF for A1 and A2")
plt.xlabel("Time to Failure (TTF)")
plt.ylabel("Frequency")
plt.show()
